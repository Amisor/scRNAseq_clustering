# %%
#!pip install scanpy
#!pip install scvi-tools
#!pip install leidenalg

# %%
# Import libraries and omit warnings
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

import scanpy as sc
import pandas as pd
import sklearn
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from anndata import AnnData
import scvi

# %% [markdown]
# # Clustering

# %%
# Read data
adata = sc.read('../data/brain_embeddings.h5ad')

# %%
# Leiden clustering
sc.tl.leiden(adata, resolution=1.0)

# %%
# K-means, GMM, and Louvain clustering - missing

# %% [markdown]
# ## PCA + clustering

# %%
# Visualize PCA colored by cluster (Leiden)
sc.pl.pca(adata, color=['mouse.id', 'leiden',])

# %%
# Visualize PCA colored by cluster (Leiden)
sc.pl.pca(adata, color=['cell_ontology_class', 'leiden',])

# %% [markdown]
# ## UMAP + clustering

# %%
# Visualize UMAP colored by cluster (Leiden)
sc.pl.umap(adata, color=['mouse.id', 'leiden'])

# %%
# Visualize UMAP colored by cluster (Leiden)
sc.pl.umap(adata, color=['cell_ontology_class', 'leiden'])

# %% [markdown]
# ## tSNE + clustering

# %%
# Visualize tSNE colored by cluster (Leiden)
sc.pl.tsne(adata, color=['mouse.id', 'leiden'])

# %%
# Visualize tSNE colored by cluster (Leiden)
sc.pl.tsne(adata, color=['cell_ontology_class', 'leiden'])

# %% [markdown]
# # Metrics

# %%
# calculate  Adjusted Rand
#Index (ARI), Homogeneity Score, Normalized Mutual Information (NMI), and Running Time for all clustering algorithms

# %% [markdown]
# Feedback: I like the proposal is very clear and organized. If time allows, you may consider additional metrics or questions such as: (1) Do some methods remove batch effects more effectively? (2) Do certain methods better identify rare cell types?
